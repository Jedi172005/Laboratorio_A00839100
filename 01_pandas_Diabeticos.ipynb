# %%
#importa librerias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn 
import numpy as np

# %% [raw]
# Pregnancies: Categórica Discreta
# Glucose: Categorica Discreta
# BloodPressure: Categorica Discreta
# SkinThickness: Cuantitativa Discreta
# Insulin: Cuantitativa Discreta
# BMI: Cuantitativa Continua
# DiabetesPedigreeFunction: Cuantitativa Continua
# Age: Cuantitativa Discreta
# Outcome: Categorica Nominak

# %%
#lee archivo.csv
diabetes = pd.read_csv("diabetes.csv")

# %%
#Funcion shape para reviar el total de renglones y columnas
diabetes.shape
# Out:
# (768, 9)

# %%
#Usa función shape para revisar el total de renglones y columnas
diabetes.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#Revisa los primeros 5 renglones del dataset usando la función head()
diabetes.tail(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
#Revisa la información mas completa del conjunto de datos usando la función info()
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
diabetes.nunique()
# Out:
# Pregnancies                  17
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %%
diabetes.describe(include='all').T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %%
diabetes.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
diabetes.Glucose.unique()
# Out:
# array([148,  85, 183,  89, 137, 116,  78, 115, 197, 125, 110, 168, 139,
#        189, 166, 100, 118, 107, 103, 126,  99, 196, 119, 143, 147,  97,
#        145, 117, 109, 158,  88,  92, 122, 138, 102,  90, 111, 180, 133,
#        106, 171, 159, 146,  71, 105, 101, 176, 150,  73, 187,  84,  44,
#        141, 114,  95, 129,  79,   0,  62, 131, 112, 113,  74,  83, 136,
#         80, 123,  81, 134, 142, 144,  93, 163, 151,  96, 155,  76, 160,
#        124, 162, 132, 120, 173, 170, 128, 108, 154,  57, 156, 153, 188,
#        152, 104,  87,  75, 179, 130, 194, 181, 135, 184, 140, 177, 164,
#         91, 165,  86, 193, 191, 161, 167,  77, 182, 157, 178,  61,  98,
#        127,  82,  72, 172,  94, 175, 195,  68, 186, 198, 121,  67, 174,
#        199,  56, 169, 149,  65, 190])

# %%
diabetes['BloodPressure'].unique()
# Out:
# array([ 72,  66,  64,  40,  74,  50,   0,  70,  96,  92,  80,  60,  84,
#         30,  88,  90,  94,  76,  82,  75,  58,  78,  68, 110,  56,  62,
#         85,  86,  48,  44,  65, 108,  55, 122,  54,  52,  98, 104,  95,
#         46, 102, 100,  61,  24,  38, 106, 114])

# %%
#Edad
#Se puede obtener la media, mediana y moda para
mean_age = diabetes['Age'].mean()
median_age =diabetes['Age'].median()
mode_age = diabetes['Age'].mode()
print("Mean_age:",mean_age)
print("Median_age:",median_age)
print("Mode_age:",mode_age)
# Out:
# Mean_age: 33.240885416666664
# Median_age: 29.0
# Mode_age: 0    22
# Name: Age, dtype: int64

# %%
#Para conteo  de cada valor en una columna, en orden descendente usar función value_counts():    
diabetes.Glucose.value_counts()
# Out:
# Glucose
# 99     17
# 100    17
# 111    14
# 125    14
# 129    14
#        ..
# 56      1
# 169     1
# 149     1
# 65      1
# 190     1
# Name: count, Length: 136, dtype: int64

# %%
diabetes['BloodPressure'].value_counts()
# Out:
# BloodPressure
# 70     57
# 74     52
# 78     45
# 68     45
# 72     44
# 64     43
# 80     40
# 76     39
# 60     37
# 0      35
# 62     34
# 66     30
# 82     30
# 88     25
# 84     23
# 90     22
# 86     21
# 58     21
# 50     13
# 56     12
# 54     11
# 52     11
# 92      8
# 75      8
# 65      7
# 85      6
# 94      6
# 48      5
# 44      4
# 96      4
# 110     3
# 106     3
# 100     3
# 98      3
# 30      2
# 46      2
# 55      2
# 104     2
# 108     2
# 40      1
# 122     1
# 95      1
# 102     1
# 61      1
# 24      1
# 38      1
# 114     1
# Name: count, dtype: int64

# %%
diabetes['Relation'] = diabetes['Glucose'] + diabetes['BMI']

# %%
diabetes['Relation'].value_counts()
# Out:
# Relation
# 156.1    4
# 131.8    4
# 124.6    4
# 151.4    4
# 137.8    4
#         ..
# 223.4    1
# 196.3    1
# 172.7    1
# 97.0     1
# 153.4    1
# Name: count, Length: 551, dtype: int64

# %%
diabetes.iloc[0]
# Out:
# Pregnancies                   6.000
# Glucose                     148.000
# BloodPressure                72.000
# SkinThickness                35.000
# Insulin                       0.000
# BMI                          33.600
# DiabetesPedigreeFunction      0.627
# Age                          50.000
# Outcome                       1.000
# Relation                    181.600
# Name: 0, dtype: float64

# %%
diabetes.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  Relation
# 0                     0.627   50        1     181.6
# 1                     0.351   31        0     111.6
# 2                     0.672   32        1     206.3
# 3                     0.167   21        0     117.1
# 4                     2.288   33        1     180.1

# %%
diabetes.iloc[:2]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
#
#    DiabetesPedigreeFunction  Age  Outcome  Relation
# 0                     0.627   50        1     181.6
# 1                     0.351   31        0     111.6

# %%
diabetes[['Glucose','BMI']]
# Out:
#      Glucose   BMI
# 0        148  33.6
# 1         85  26.6
# 2        183  23.3
# 3         89  28.1
# 4        137  43.1
# ..       ...   ...
# 763      101  32.9
# 764      122  36.8
# 765      121  26.2
# 766      126  30.1
# 767       93  30.4
#
# [768 rows x 2 columns]

# %%
diabetes[diabetes['Outcome'] == 0 ]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  Relation
# 1                       0.351   31        0     111.6
# ...

# %%
Diabeticos = diabetes[diabetes['Outcome'] == 1 ]

# %%
Diabeticos.head(50)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 11            10      168             74              0        0  38.0
# 13             1      189             60             23      846  30.1
# 14             5      166             72             19      175  25.8
# 15             7      100              0              0        0  30.0
# 16             0      118             84             47      230  45.8
# 17             7      107             74              0        0  29.6
# ...

# %%
Diabeticos.sort_values(by='Age', ascending=False)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 666            4      145             82             18        0  32.5
# 363            4      146             78              0        0  38.5
# 221            2      158             90              0        0  31.6
# 759            6      190             92              0        0  35.5
# 579            2      197             70             99        0  34.7
# ..           ...      ...            ...            ...      ...   ...
# 414            0      138             60             35      167  34.6
# 220            0      177             60             29      478  34.6
# 580            0      151             90             46        0  42.1
# 255            1      113             64             35        0  33.6
# 577            2      118             80              0        0  42.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 666                     0.235   70        1
# ...

# %%
Diabeticos.groupby('Pregnancies')['BMI'].mean()
# Out:
# Pregnancies
# 0     39.213158
# 1     37.793103
# 2     34.578947
# 3     32.548148
# 4     33.873913
# 5     36.780952
# 6     31.775000
# 7     34.756000
# 8     32.204545
# 9     33.300000
# 10    31.380000
# 11    39.385714
# 12    34.575000
# 13    36.720000
# 14    35.100000
# 15    37.100000
# 17    40.900000
# Name: BMI, dtype: float64

# %%
Diabeticos = diabetes['Outcome'].value_counts()
Diabeticos.plot(kind='bar')
plt.title('Distribucion de Diabeticos')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #analisis de variables

# %% [markdown]
# Analisis[['Glucose','BMI']] = diabetes[['Glucose','BMI']]

# %%
diabetes[['Glucose','BMI']].head(10).value_counts()
# Out:
# Glucose  BMI
# 78       31.0    1
# 85       26.6    1
# 89       28.1    1
# 115      35.3    1
# 116      25.6    1
# 125      0.0     1
# 137      43.1    1
# 148      33.6    1
# 183      23.3    1
# 197      30.5    1
# Name: count, dtype: int64

# %%
diabetes.groupby('Glucose')['BMI'].min()
# Out:
# Glucose
# 0      24.7
# 44     25.0
# 56     24.2
# 57     21.7
# 61     34.4
#        ...
# 195    25.1
# 196    36.5
# 197    25.9
# 198    41.3
# 199    42.9
# Name: BMI, Length: 136, dtype: float64

# %%
diabetes.groupby('BMI')['Glucose'].max()
# Out:
# BMI
# 18.2     97.0
# 18.4    104.0
# 19.1     80.0
# 19.3     99.0
# 19.4    103.0
#         ...
# 53.2    162.0
# 55.0     88.0
# 57.3    123.0
# 59.4    180.0
# 67.1    129.0
# Name: Glucose, Length: 247, dtype: float64

# %%
Analisis = diabetes[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']].agg(['min','max','mean','median','std']).T
Analisis['range'] = Analisis['max'] - Analisis['min']
Analisis['mode']  = diabetes[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']].mode().iloc[0]
Analisis
# Out:
#                              min     max        mean    median         std  \
# Pregnancies                0.000   17.00    3.845052    3.0000    3.369578
# Glucose                    0.000  199.00  120.894531  117.0000   31.972618
# BloodPressure              0.000  122.00   69.105469   72.0000   19.355807
# SkinThickness              0.000   99.00   20.536458   23.0000   15.952218
# Insulin                    0.000  846.00   79.799479   30.5000  115.244002
# BMI                        0.000   67.10   31.992578   32.0000    7.884160
# DiabetesPedigreeFunction   0.078    2.42    0.471876    0.3725    0.331329
# Age                       21.000   81.00   33.240885   29.0000   11.760232
#
#                             range    mode
# Pregnancies                17.000   1.000
# Glucose                   199.000  99.000
# BloodPressure             122.000  70.000
# SkinThickness              99.000   0.000
# Insulin                   846.000   0.000
# ...

# %%
Analisis = diabetes[['Pregnancies', 'Glucose', 'BloodPressure','SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']].agg(['min','max','mean','median','std']).T
Analisis['range'] = Analisis['max'] - Analisis['min']
Analisis['mode']  = diabetes[['Pregnancies', 'Glucose', 'BloodPressure','SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']].mode().iloc[0]
Analisis
# Out:
#                              min     max        mean    median         std  \
# Pregnancies                0.000   17.00    3.845052    3.0000    3.369578
# Glucose                    0.000  199.00  120.894531  117.0000   31.972618
# BloodPressure              0.000  122.00   69.105469   72.0000   19.355807
# SkinThickness              0.000   99.00   20.536458   23.0000   15.952218
# Insulin                    0.000  846.00   79.799479   30.5000  115.244002
# BMI                        0.000   67.10   31.992578   32.0000    7.884160
# DiabetesPedigreeFunction   0.078    2.42    0.471876    0.3725    0.331329
# Age                       21.000   81.00   33.240885   29.0000   11.760232
# Outcome                    0.000    1.00    0.348958    0.0000    0.476951
#
#                             range    mode
# Pregnancies                17.000   1.000
# Glucose                   199.000  99.000
# BloodPressure             122.000  70.000
# SkinThickness              99.000   0.000
# ...

# %%
Diabeticos.head(50)
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
#Se puede ver con esta tabla que hay una relacion entre que tan altos son los valores de BMI, Insulin, Glucose y BloodPressure para determinar si el paciente es
#o va a ser diabetico, ya que podemos observar que la mayoria de los datos que estan con el outcome 0 tienen el BMI elevado, la glucosa elevado y todos los otros datos 
#elevados.

# %%
Diabeticos = diabetes['Outcome'].value_counts()
Diabeticos.plot(kind='bar')
plt.title('Distribucion de Diabeticos')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Podemos ver que hay una cantidad de diabeticos bastante mas alta que la de no diabeticos, esto tiene sentido viendo los min, max, median de las variables, ya que estas
#muestran que los means tienden a ser relativamente altos, y al igual que con la tabla pasada, podemos llegar a la conclusion que entre mas alto esos datos, mas 
#probabilidad de que uno tenga diabetes. A traves de esta grafica podemos confirmar esto, viendo que en su mayoria, hay mas diabeticos que no diabeticos.

# %%
# Distribucion por clase
diabetes['Glucose'].value_counts().plot(kind='bar', title='Distribución por Glucosa')
plt.show()

# %%
## Se puede ver aqui la frecuencia en la que cada cantidad de embarazos ocurrieron en los pacientes. Se puede ver que las 5 cantidades de embarazo mas frecuentes son
## 1 embarazo, 0 embarazos, 2, 3 y 4 embarazos. Despues de eso comienza a bajar bastante la frecuencia de los embarazos, con la frecuencia mas pequeña siendo la de 15.

# %%
Diabeticos.groupby('Glucose')['BMI'].mean()
# Out:
# Glucose
# 0      40.000000
# 78     31.000000
# 80     34.200000
# 84     29.700000
# 85     29.000000
#          ...
# 195    28.000000
# 196    37.933333
# 197    30.366667
# 198    41.300000
# 199    42.900000
# Name: BMI, Length: 104, dtype: float64

# %%
diabetes[['Glucose', 'BMI']].hist(figsize=(10,5))
plt.show()

# %%
## Se puede ver que en age se tiene un sesgo a la izquierda, que en este caso signfica que la mayoria de las personas tienen edades cercanas a los 20-30 años de edad, 
## a pesar de que el rango llega hasta los 81 años de edad. En el BMI, se puede notar que es bastante simetrico, ya que la mayoria de los datos estan entre los 20 y 40
## de BMI, pero si se puede notar un outlier, de 0, que probablemente sea una lectura incorrecta.

# %%
diabetes.boxplot(column='Age')
plt.title('Boxplot de Edad')
plt.ylabel('Edad (años)')
plt.show()

# %%
## Se puede ver que tiene un rango de 21 años a alrededor de 67 años, con la media estando entre los 23 años hasta los 41. Tambien podemos observar que existen unos 
## outliers mayores, ya que hay varias edades que estan por encima del limite del rango normal, llegando hasta edades como 81.

# %%
sns.boxplot(diabetes['Age'])
plt.title('Boxplot de Edad')
# Out:
# Text(0.5, 1.0, 'Boxplot de Edad')

# %%
## Se puede apreciar en el boxplot de edad que la mayoria de los pacientes tienen unas edades de entre 24 años y 41 años. A pesar de esto el rango normal va desde 
##alrededor de los 21 años hasta alrededor de los 65 años. Se pueden apreciar unos cuantos outliers, con personas superando la edad normal del rango con edades arriba 
## de 65 años.

# %%
q1, mediana, q3 = np.percentile(diabetes['Age'], [25, 50, 75])
print("El 25% de las personas tienen edad debajo de", q1)
print("El 25% de las personas tienen edad arriba de", q3)
# Out:
# El 25% de las personas tienen edad debajo de 24.0
# El 25% de las personas tienen edad arriba de 41.0

# %%
sns.boxplot(diabetes, x="Outcome", y="Glucose")
plt.title("Glucosa de acuerdo a pacientes con diabetes")
# Out:
# Text(0.5, 1.0, 'Glucosa de acuerdo a pacientes con diabetes')

# %%
## Podemos ver en este boxplot y la comparacion que, para las personas que no tienen diabetes, existen de un rango de alredeor de 55 de glucosa hasta 175 de glucosa
## Para las personas que si tienen diabetes, el rango va desde alrededor de 80 de glucosa hasta 200 de glucosa. La media de las personas que no tienen diabetes
## esta entre los 90 y 125 de glucosa, mientras que el de las personas con diabetes este entre los 120 de glucosa hasta los 170 de glucosa. Solo existen outliers
## en el caso de las personas que no tienen diabetes, superando los niveles normales del rango de glucosa.

# %%
sns.boxplot(diabetes, x="Outcome", y="BMI")
plt.title("BMI de acuerdo a pacientes con diabetes")
# Out:
# Text(0.5, 1.0, 'BMI de acuerdo a pacientes con diabetes')

# %%
## Podemos ver que el BMI de las personas sin diabetes va desde los 19 hasta alrededor de 47, mientras que las personas con diabetes tienen un rango de BMI desde
## los 23 hasta alrededor de los 51. La media de las personas sin diabetes es de un BMI entre 25 y 35, mientras que el de las personas con diabetes esta entre 31 y 37.
## Finalmente, podemos ver que existen outliers en ambos casos, igual inferiores y superiores.

# %%
variables_numericas = diabetes.select_dtypes(include='number')
matriz_correlation = variables_numericas.corr().round(2)
matriz_correlation
# Out:
#                           Pregnancies  Glucose  BloodPressure  SkinThickness  \
# Pregnancies                      1.00     0.13           0.21           0.10
# Glucose                          0.13     1.00           0.22           0.23
# BloodPressure                    0.21     0.22           1.00           0.23
# SkinThickness                    0.10     0.23           0.23           1.00
# Insulin                          0.08     0.58           0.10           0.18
# BMI                              0.02     0.23           0.29           0.65
# DiabetesPedigreeFunction        -0.03     0.13          -0.00           0.12
# Age                              0.54     0.26           0.33           0.17
# Outcome                          0.22     0.49           0.17           0.26
#
#                           Insulin   BMI  DiabetesPedigreeFunction   Age  \
# Pregnancies                  0.08  0.02                     -0.03  0.54
# ...

# %%
## Se puede notar ciertas relaciones fuertes, como puede ser Age con el numero de pregnancies, al igual que el glucosa y BMI con el outcome. Otras que resaltan
## son las de insulina con la glucosa, con un valor de 0.33.

# %%
sns.heatmap(matriz_correlation, annot=True)
plt.title('Correlacion entre caracteristicas (Features)')
# Out:
# Text(0.5, 1.0, 'Correlacion entre caracteristicas (Features)')

# %%
## Aqui tenemos una vista mas facil de analizar sobre como estan las correlaciones de estos datos.

# %%
diabetes.loc[diabetes['Glucose'] == 0, 'Glucose'] = pd.NA
diabetes.loc[diabetes['BMI'] == 0, 'BMI'] = pd.NA
diabetes.loc[diabetes['SkinThickness'] == 0, 'SkinThickness'] = pd.NA
diabetes.loc[diabetes['Insulin'] == 0, 'Insulin'] = pd.NA
diabetes.loc[diabetes['BloodPressure'] == 0, 'BloodPressure'] = pd.NA

# %%
diabetes.describe(include='all')
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  752.000000     733.000000     541.000000  394.000000
# mean      3.845052  121.941489      72.405184      29.153420  155.548223
# std       3.369578   30.601198      12.382158      10.476982  118.775855
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      22.000000   76.250000
# 50%       3.000000  117.000000      72.000000      29.000000  125.000000
# 75%       6.000000  141.000000      80.000000      36.000000  190.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  757.000000                768.000000  768.000000  768.000000
# mean    32.457464                  0.471876   33.240885    0.348958
# std      6.924988                  0.331329   11.760232    0.476951
# ...

# %%
Analisis = diabetes[['Pregnancies', 'Glucose', 'BloodPressure','SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']].agg(['min','max','mean','median','std']).T
Analisis['range'] = Analisis['max'] - Analisis['min']
Analisis['mode']  = diabetes[['Pregnancies', 'Glucose', 'BloodPressure','SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']].mode().iloc[0]
Analisis
# Out:
#                              min     max        mean    median         std  \
# Pregnancies                0.000   17.00    3.845052    3.0000    3.369578
# Glucose                   44.000  199.00  121.941489  117.0000   30.601198
# BloodPressure             24.000  122.00   72.405184   72.0000   12.382158
# SkinThickness              7.000   99.00   29.153420   29.0000   10.476982
# Insulin                   14.000  846.00  155.548223  125.0000  118.775855
# BMI                       18.200   67.10   32.457464   32.3000    6.924988
# DiabetesPedigreeFunction   0.078    2.42    0.471876    0.3725    0.331329
# Age                       21.000   81.00   33.240885   29.0000   11.760232
# Outcome                    0.000    1.00    0.348958    0.0000    0.476951
#
#                             range     mode
# Pregnancies                17.000    1.000
# Glucose                   155.000   99.000
# BloodPressure              98.000   70.000
# SkinThickness              92.000   32.000
# ...

# %%
diabetes[['Glucose', 'BMI']].hist(figsize=(10,5))
plt.show()

# %%
sns.boxplot(diabetes['Glucose'])
plt.title('Boxplot de Glucosa')
# Out:
# Text(0.5, 1.0, 'Boxplot de Glucosa')

# %%
sns.boxplot(diabetes['BMI'])
plt.title('Boxplot de BMI')
# Out:
# Text(0.5, 1.0, 'Boxplot de BMI')
